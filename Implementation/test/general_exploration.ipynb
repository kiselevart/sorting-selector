# %%
import sys
import os

# Add the build directory to Python path
build_dir = os.path.abspath('../')
sys.path.insert(0, build_dir)

import pandas as pd
import numpy as np

import sorters
from data import list_generators

# %%
dataset = []
for i in range(100):
    dataset.append(list_generators.randomize_list(list_generators.generate_list(1000)))

print(dataset)
# Out:
# [[793, 210, 673, 606, 36, 623, 411, 212, 300, 829, 231, 854, 816, 834, 985, 650, 723, 440, 845, 915, 459, 759, 169, 13, 136, 568, 959, 786, 19, 465, 478, 438, 986, 500, 966, 63, 798, 821, 810, 492, 255, 106, 580, 876, 332, 488, 918, 85, 250, 287, 21, 639, 185, 628, 850, 946, 792, 702, 739, 889, 898, 545, 56, 274, 129, 460, 583, 921, 887, 435, 619, 486, 587, 965, 866, 795, 417, 961, 538, 46, 745, 482, 400, 112, 117, 225, 119, 562, 111, 415, 551, 339, 377, 30, 179, 601, 669, 317, 469, 54, 765, 58, 943, 428, 629, 3, 217, 48, 575, 218, 294, 517, 191, 334, 318, 0, 458, 177, 298, 706, 383, 401, 464, 763, 683, 748, 553, 61, 956, 481, 896, 620, 60, 475, 494, 103, 841, 97, 446, 852, 233, 273, 980, 87, 79, 352, 556, 501, 166, 807, 539, 493, 715, 881, 480, 693, 768, 176, 782, 366, 243, 17, 675, 132, 877, 194, 296, 23, 272, 453, 597, 770, 261, 728, 653, 802, 599, 307, 227, 423, 402, 385, 689, 791, 130, 916, 830, 50, 803, 878, 788, 113, 790, 439, 591, 907, 516, 141, 94, 931, 511, 717, 20, 509, 14
# ...

# %%
time = sorters.benchmark_sorter("insertion_sort", dataset)
